# %% [markdown]
# # This notebook will help you to do:
# * Import training and test data
# * Run many ML algorithms using H2O
# * Compare all model performance in test dataset
# * Choosing the best model
# * Interpret model output with Shapley Value

# %% [markdown]
# # 1. Parameters

# %%
#Model ID
ModelId='prop_abordagens_v5'

#Setting the model target variable name
var_target = 'target'

#process outputs such as MOJO model, images and performance of tested models
OutputPath='D:\\OneDrive\\INTERA\\Data\\Data_Science\\propensao_abordagem\\output_model'

#If you have a huge dataset, I should consider use a small sample for first execution
pct_sample_size = 1

# %% [markdown]
# # 2. Import Libraries

# %%
import glob
import functools
import datetime as dt
import pandas as pd
import numpy as np
import h2o
import matplotlib.pyplot as plt
import shap
from pandas_profiling import ProfileReport
from collections import defaultdict
from pandas_profiling.model.base import get_var_type
import seaborn as sns
import os
import random
import os
import pandas as pd
import pymysql
import sqlalchemy as sa
from pandas_profiling import ProfileReport
from plotly import graph_objects as go
import boto3
from boto3.dynamodb.conditions import Key
from pyathena import connect
import awswrangler as wr

# %% [markdown]
# # 3. Importing Data for Modeling

# %%
# Creating context and H2O and Importing data into the H2O context
# Number of threads, nthreads = -1, means use all cores on your machine
# max_mem_size is the maximum memory (in GB) to allocate to H2O
h2o.init(nthreads = -1, max_mem_size = 8)
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321 ..... not found.
# Attempting to start a local H2O server...
# ; Java HotSpot(TM) 64-Bit Server VM (build 25.261-b12, mixed mode)
#   Starting server from c:\program files\python37\lib\site-packages\h2o\backend\bin\h2o.jar
#   Ice root: C:\Users\maxde\AppData\Local\Temp\tmpty6pnb11
#   JVM stdout: C:\Users\maxde\AppData\Local\Temp\tmpty6pnb11\h2o_maxde_started_from_python.out
#   JVM stderr: C:\Users\maxde\AppData\Local\Temp\tmpty6pnb11\h2o_maxde_started_from_python.err
# ---------------------------------------------------------------------------
# H2OConnectionError                        Traceback (most recent call last)
# c:\program files\python37\lib\site-packages\h2o\h2o.py in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, max_log_file_size, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, **kwargs)
#     265                                            "connected.", "not found."),
# --> 266                                      strict_version_check=svc)
#     267     except H2OConnectionError:
#
# c:\program files\python37\lib\site-packages\h2o\backend\connection.py in open(server, url, ip, port, name, https, auth, verify_ssl_certificates, cacert, proxy, cookies, verbose, msgs, strict_version_check)
#     385             conn._timeout = 3.0
# --> 386             conn._cluster = conn._test_connection(retries, messages=msgs)
#     387             # If a server is unable to respond within 1s, it should be considered a bug. However we disable this
#
# c:\program files\python37\lib\site-packages\h2o\backend\connection.py in _test_connection(self, max_retries, messages)
#     690             raise H2OConnectionError("Could not establish link to the H2O cloud %s after %d retries\n%s"
# --> 691                                      % (self._base_url, max_retries, "\n".join(errors)))
#     692
#
# H2OConnectionError: Could not establish link to the H2O cloud http://localhost:54321 after 5 retries
# [22:46.43] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001885B84A648>: Failed to establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente'))
# [22:50.73] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001885B8661C8>: Failed to establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente'))
# [22:55.04] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001885B87E588>: Failed to establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente'))
# [22:59.35] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001881B6D5F08>: Failed to establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente'))
# [23:03.61] H2OConnectionError: Unexpected HTTP error: HTTPConnectionPool(host='localhost', port=54321): Max retries exceeded with url: /3/Metadata/schemas/CloudV3 (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001885B866488>: Failed to establish a new connection: [WinError 10061] Nenhuma conexão pôde ser feita porque a máquina de destino as recusou ativamente'))
#
# During handling of the above exception, another exception occurred:
#
# H2OServerError                            Traceback (most recent call last)
# <ipython-input-5-bcf5bd1f9dc5> in <module>
#       2 # Number of threads, nthreads = -1, means use all cores on your machine
#       3 # max_mem_size is the maximum memory (in GB) to allocate to H2O
# ----> 4 h2o.init(nthreads = -1, max_mem_size = 8)
#
# c:\program files\python37\lib\site-packages\h2o\h2o.py in init(url, ip, port, name, https, cacert, insecure, username, password, cookies, proxy, start_h2o, nthreads, ice_root, log_dir, log_level, max_log_file_size, enable_assertions, max_mem_size, min_mem_size, strict_version_check, ignore_config, extra_classpath, jvm_custom_args, bind_to_localhost, **kwargs)
#     280                                   max_log_file_size=max_log_file_size, port=port, name=name,
#     281                                   extra_classpath=extra_classpath, jvm_custom_args=jvm_custom_args,
# --> 282                                   bind_to_localhost=bind_to_localhost)
#     283         h2oconn = H2OConnection.open(server=hs, https=https, verify_ssl_certificates=verify_ssl_certificates,
#     284                                      cacert=cacert, auth=auth, proxy=proxy, cookies=cookies, verbose=True,
#
# c:\program files\python37\lib\site-packages\h2o\backend\server.py in start(jar_path, nthreads, enable_assertions, max_mem_size, min_mem_size, ice_root, log_dir, log_level, max_log_file_size, port, name, extra_classpath, verbose, jvm_custom_args, bind_to_localhost)
#     140         hs._launch_server(port=port, baseport=baseport, nthreads=int(nthreads), ea=enable_assertions,
#     141                           mmax=max_mem_size, mmin=min_mem_size, jvm_custom_args=jvm_custom_args,
# --> 142                           bind_to_localhost=bind_to_localhost, log_dir=log_dir, log_level=log_level, max_log_file_size=max_log_file_size)
#     143         if verbose: print("  Server is running at %s://%s:%d" % (hs.scheme, hs.ip, hs.port))
#     144         atexit.register(lambda: hs.shutdown())
#
# c:\program files\python37\lib\site-packages\h2o\backend\server.py in _launch_server(self, port, baseport, mmax, mmin, ea, nthreads, jvm_custom_args, bind_to_localhost, log_dir, log_level, max_log_file_size)
#     361                 else:
#     362                     error_message += "."
# --> 363                 raise H2OServerError(error_message)
#     364             ret = self._get_server_info_from_logs()
#     365             if ret:
#
# H2OServerError: Server process terminated with error code 1: ERROR: failed in createLog4j, exiting now.
# java.lang.NullPointerException
# 	at water.util.Log.createLog4j(Log.java:349)
# 	at water.util.Log.write0(Log.java:139)
# 	at water.util.Log.flushBufferedMessages(Log.java:156)
# 	at water.util.Log.notifyAboutProcessExiting(Log.java:78)
# 	at water.H2O.exit(H2O.java:948)
# 	at water.H2O.parseFailed(H2O.java:465)
# 	at water.H2O.parseH2OArgumentsTo(H2O.java:760)
# 	at water.H2O.parseArguments(H2O.java:529)
# 	at water.H2O.main(H2O.java:2184)
# 	at water.H2OStarter.start(H2OStarter.java:22)
# 	at water.H2OStarter.start(H2OStarter.java:48)
# 	at water.H2OApp.main(H2OApp.java:12)

# %%
#If you want to choose a model other than the first one on the list. Choose the position number:
posicao_melhor_modelo=1

melhor_modelo = h2o.load_model('%s/models/todos/%s' % (OutputPath, modelos_testados.iloc[posicao_melhor_modelo, 0]))
(print("\n"+ "BEST MODEL: " + str(modelos_testados.iloc[posicao_melhor_modelo, 0]) + "\n"))

plt.rcParams.update({'font.size': 10})
try:
    melhor_modelo.varimp_plot(50)
except Exception as e:
    print("Warning: This model doesn't have variable importances")
# Out:
# BEST MODEL: GBM_grid__1_AutoML_20220323_233606_model_53

# %% [markdown]
# ## 6.5 Exporting the best model to Deploy

# %%
#Save the H2O model in MOJO format and all the variables of the best model
melhor_modelo = h2o.load_model('%s/models/todos/%s' % (OutputPath, modelos_testados.iloc[posicao_melhor_modelo, 0]))
caminho_modelo_mojo = melhor_modelo.download_mojo('%s/models/melhores/' % OutputPath, get_genmodel_jar=True)
print(caminho_modelo_mojo)
caminho_modelo_h2o = h2o.save_model(model=melhor_modelo, path='%s/models/melhores/' % OutputPath, force=True)
# Out:
# D:\OneDrive\INTERA\Data\Data_Science\propensao_abordagem\output_model\models\melhores\GBM_grid__1_AutoML_20220323_233606_model_53.zip

# %%
try:
    features_names= melhor_modelo.varimp(True)
    features_names.to_csv('%s/models/melhores/features_names_%s.csv' % (OutputPath, melhor_modelo.model_id), sep=';')
except Exception as e:
    print("Warning: This model doesn't have variable importances")

# %% [markdown]
# # 7. Calculate Shapley Values using SHAP KernelExplainer for H20 models

# %% [markdown]
# #### The SHAP library calculates the Shaley Value of each variable used in the model and shows the individual impact of each variable on the predicted value for each record. To better understand how the SHAP library works, see the link https://github.com/slundberg/shap

# %%
class H2oProbWrapper:
    def __init__(self, h2o_model, feature_names):
        self.h2o_model = h2o_model
        self.feature_names = feature_names
    def predict_binary_prob(self, X):
        if isinstance(X, pd.Series):
            X = X.values.reshape(1,-1) 
        self.dataframe = pd.DataFrame(X, columns=self.feature_names)
        
        global NUM
        #Variaveis explicativas continuas
        for col_name in NUM:    
            self.dataframe[col_name] = self.dataframe[col_name].astype(float)
            
        global CAT
        for col_name in CAT:    
            self.dataframe[col_name] = self.dataframe[col_name].astype(str)
            self.dataframe = self.dataframe.fillna(value={col_name: 'missing'})
        
        self.h2oframe = h2o.H2OFrame(self.dataframe)
        for col_name in CAT:
            self.h2oframe[col_name] = self.h2oframe[col_name].asfactor()
        
        self.predictions = self.h2o_model.predict(self.h2oframe).as_data_frame().values
        return self.predictions.astype('float64') [:,-1]

# %%
#The calculation of the Shapley Value for H20 models takes a while. So it will only be done for 20 records. Increase the sample to deepen your analysis
shap_sample = dataprep_df.query('dataset == "test"').loc[:,(selected_features)].sample(n=22, replace=False, random_state=1)
shap_sample = shap_sample.fillna(0)

# %%
h2o_wrapper = H2oProbWrapper(melhor_modelo, selected_features)
h2o_explainer = shap.KernelExplainer(h2o_wrapper.predict_binary_prob, shap_sample)
h2o_shap_values = h2o_explainer.shap_values(shap_sample, nsamples="auto")
# Out:
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# HBox(children=(HTML(value=''), FloatProgress(value=0.0, max=22.0), HTML(value='')))
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%
# Parse progress: |█████████████████████████████████████████████████████████| 100%
# gbm prediction progress: |████████████████████████████████████████████████| 100%

# %% [markdown]
# ## Main SHAP Graphics

# %%
fig = shap.summary_plot(h2o_shap_values, shap_sample, plot_type="bar", show=True)
display(fig)
# Out:
# None

# %%
display(shap.summary_plot(h2o_shap_values, shap_sample, show=False))
# Out:
# None

# %%
#sort the features indexes by their importance in the model
#(sum of SHAP value magnitudes over the validation dataset)
top_inds = np.argsort(-np.sum(np.abs(h2o_shap_values),0))

#make SHAP plots of the three most important features
for i in range(9):
    fig=shap.dependence_plot(top_inds[i], h2o_shap_values, shap_sample, show=False)
#     display(fig)

# %%
df_shap_values = pd.DataFrame(h2o_shap_values)
df_shap_values['sum_shap'] = df_shap_values.sum(axis=1)

# %% [markdown]
# ### Shap Force Plot

# %%
for i in df_shap_values.sort_values(by='sum_shap').iloc[0:3,:].index.values:
    fig = shap.force_plot(h2o_explainer.expected_value, h2o_shap_values[i,:], shap_sample.iloc[i,:], matplotlib=True, show=True)
    display(fig)
# Out:
# None
# None
# None

# %% [markdown]
# ### Shap Waterfall Plot

# %%
for i in df_shap_values.sort_values(by='sum_shap').iloc[0:3,:].index.values:
    fig = shap.plots._waterfall.waterfall_legacy(h2o_explainer.expected_value, h2o_shap_values[i,:], shap_sample.iloc[i,:].to_numpy(), selected_features, show=True)
    display(fig)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-13395e2c7f55> in <module>
# ----> 1 for i in df_shap_values.sort_values(by='sum_shap').iloc[0:3,:].index.values:
#       2     fig = shap.plots._waterfall.waterfall_legacy(h2o_explainer.expected_value, h2o_shap_values[i,:], shap_sample.iloc[i,:].to_numpy(), selected_features, show=True)
#       3     display(fig)
#
# NameError: name 'df_shap_values' is not defined

# %% [markdown]
# ## END
